# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
# %pip install google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 채널 ID구하기

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
from oauth2client.tools import argparser
import requests
from bs4 import BeautifulSoup


# https://console.cloud.google.com/apis/credentials 여기서 API발급받아 사용
DEVELOPER_KEY='AIzaSyARrUg67ItiYT-d7vOnfp2Uo6otQQHYM5U' # 내 API 키값 입력
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube=build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
# q에 원하는 채널 이름 넣는다
search_response=youtube.search().list(
    q="할명수",
    order='relevance',
    part='snippet',
    type='channel',
    maxResults=50,
    ).execute()

# %%
# print(len(search_response['items']))
for i in range(len(search_response['items'])):
    print(search_response['items'][i]['id']['channelId'])
# Out:
# UCmbGE7Y2ov7pTBuUrkXgtTQ
# UCUsPbI9kRlQMxKj5gPv4TFw
# UCkyXMxv_Qj1EzZIdTpYoN8A
# UCAhXBfMX4bUb_T1jq8AsUCw
# UCsNts2XkRF_RNzYnLbSmYQg
# UCNvzfHyFuiLdOSlHLJvTcoQ
# UChuU-14NZ658OREXhzbYA1w
# UCI8sCAriSevoQTiCj02rm6w
# UCXmIvXtWCP8YifB__Kwdq-g
# UCKugotGOqQ6huKR3cTTnd0g
# UCfHuFkIfq7iMi4RXIgmOdZw
# UChYiw2RWoXfiEqamkQ22EbA
# UC0B9Q0y9_V6vwiAr0SFXTmw
# UCkDBOWfpxEY75IaARfZclFw
# UCG1qUtS4PGfcwza48uRTGXg
# UCsRwTiKvawMilxrk9KiHDGQ
# UCeVnZDkGV-N_fp5E5mqFLbQ
# UC4d4XGqfnPa4enMiyLIFv9A
# UCD6FekEiU_eiT374wxSFprA
# UCcn85dtMRHAyQu1lms7zaVw
# UCZJQWtNF8T0NCOiZmK0_5KA
# UCXZlIrxtpqSEKQ4kcvPGD-w
# UCIlivRyBi9UZ5D8egypS4kg
# UCYBJ7UJ346O7RsbYpGyDDpg
# UCehOxaxkVMLuav7C_gUKE-A
# UC5oWEe-7Iv2REU6cZPQPEFg
# UCnw8ViMkkYfjcwLDe28696Q
# UCQAkfDiA92wuN68bNoCa1rQ
# UC3xlfn2v_WihwcYOYXe_rgw
# UCZRruktPOtiJoQvlGIhJFqA
# UCWH1X1ShWov81j03vJEp2VA
# UCJFXh6hyNKkWbH0_pgwhO5Q
# UCfYCpgfTXpaUJ8oIUfMCUWg
# UCKzwkXxPQOhhBVbDDTQElOg
# UCAhm_augCdPuAipKbGtvdjA
# UCau5FLJpMxhvW-IHZ8c8qKQ
# UCkeCeQzACGAcVR0cye9zhLQ
# ...

# %% [markdown]
# DataFrame으로 변환

# %%
api_key = 'AIzaSyARrUg67ItiYT-d7vOnfp2Uo6otQQHYM5U'
#channel_id = 'UCnz-ZXXER4jOvuED5trXfEA'
channel_ids = ['UC0SoPwEH3idvemSDvKaYgGA', # 1. 달라스튜디오
               'UC0w2Xg4UB8ip-QnZnHpFB-g', # 2. 재롱잔치
               'UCMZNsnZXi7IZZbCaPjjFBHw', # 3. 지윤일기
               'UCKurJtf5TWo5nrq8nnuvrcg', # 4. 꽉잡아윤기
               'UCQ2O-iftmnlfrBuNsUUTofQ', # 5. 채널 십오야
               'UCr9fTGseL8WjLl0A_RubtZw', # 6. 보통견주
               'UC3fPnB3ds2xBY1PTtgkCCYw', # 7. ASTER MUSIC
               'UC98TOxKQk4aLcx0EjIK0LkQ', # 8. 해수인 tv
               'UClWx6swfFdNod4hMeT27BBA', # 9. 나는식물원에살고있다
               'UCLmeWUramUY8YAQ6A40Ionw', # 10. 무지막지한 막무가네
               'UCGX5sP4ehBkihHwt5bs5wvg', # 11. 피식대학
               'UCXe53j9Mq0rAWmbIzOMF9fw', # 12. '배배자매-BaeBae vlog'
               'UCK72hqlUxI_E5VwL4cy8-ww', # 13. '웅이woongei'
               'UCfpaSruWW3S4dibonKXENjA', # 14. tzuyang쯔양
               'UCoe-0EVDJnjlSoPK8ygcGwQ', # 15. 김종국 GYM JONG KOOK
               'UCVut4hqvrjQC4qDE3oc5qig', # 16. 때껄룩ᴛᴀᴋᴇ ᴀ ʟᴏᴏᴋ
               'UCOp66Vup07X0YziXaaxqs2A', # 17. 'haha ha'
               'UCsbVGDDMTToaOwbzEK0_6Vg', # 18. 새덕후 Korean Birder
               'UCyozK5OFN5lDrwim5wqQnLA', # 19. 취미로 요리하는 남자 Yonam
               'UCqNb520-5yjk3GGkLw73EgQ', # 20. 리틀면지
               'UCTx3aCntDvkq-hGtOjKVSnQ', # 21. 먹어볼래TryToEat
               'UCZTavrg2A43lQMWxiK3yu7g', # 22. 한세 HANSE
               'UCEdim_OY8EE4lmPqjEZQ8QQ', # 23. 르은 r-eun
               'UC6KwCU8Y8Uw4h_Q0ptLZkqw', # 24. 해쭈 [HAEJOO]
               'UC84Zkx_92divh3h4sKXeDew', # 25. 서담 seodam
               'UCQg7opkHC1IIHYsIRuivMbw', # 26. 무니키친MoonyKitchen
               'UCZ_njPaFCKrZcMQV6VFK6sw', # 27. 제이크 토익스피킹
               'UCjTXdp_F74xwU6snSdcndag', # 28. 떴다왕언니
               'UCve8t5HXOTE6k6hdBao31SA', # 29. 도시오리 CityDuck
               'UCAnRxvo1K79GlQweJ4yeZsg', # 30. 쏘쏘한베이킹 sosobaking
               'UCx-cKLK2mSsstFZGFjbCraA', # 31. 빵먹다살찐떡
               'UCEsd9DjhmXwb9shfaSSFr7w', # 32. Daram Table다람테이블
               'UCa1hPHIwVvkNcFBRpCAxfMA', # 33. 오늘내일 TodyTomy
               'UC2viazvlrvicBWCIWHKd70Q', # 32. 레어리RareLee
               'UC3dJKwKxhR1Boz56EsI5PYQ', # 33. 이영지
               'UCkuA_gDjISfGgbdp02BUwyQ', # 34. 크집사
               'UCtCiO5t2voB14CmZKTkIzPQ', # 35. 딩고 뮤직 / dingo music
               'UCxwV8yo7Wj2BUfwTmonv8IQ', # 36. 10준수
               'UCsMLh3wC-xETim34EYs9lYw', # 37. 브라보현
               'UCnFFOjljp1_sacTz7PfIIyg', # 38. LeoJ Makeup
               'UCL0DDCStyO4NeAFJoN_cO8Q', # 39. 멜로우 Mallow
               'UCfak21UYFUer7Nhucu3CuJA', # 40. Cozy Rain
               'UCSGC87iX0QhnIfUOI_B_Rdg', # 41. essential;
               'UCuTKrQEt651z729A9-S8hZw', # 42. 바라던 바다
               'UCiKEFY49JIvpOOdTHgsWQHw', # 42. H녀
               'UCAyvCxdhYV-Zg7PSGZJoQ2A', # 43. 썰플리
               'UCDNvRZRgvkBTUkQzFoT_8rA', # 44. 뜬뜬 DdeunDdeun
               'UCj5bc4HjUsRyz8kVso7XZzQ', # 45. 박웅장
               'UCHZC1dzg8eQ_I6ttZNdNQgg', # 46. 퍼플리셔스ᴘᴜʀᴘʟɪᴄɪᴏᴜs
               'UCVaPTUuJy7tFC8YAYW6GRqw', # 47. yedy101
               'UCtby6rJtBGgUm-2oD_E7bzw', # 48. Cooking tree 쿠킹트리
               'UCGiqkgSsKPWI3Sn4mGs54fw', # 49. 무쇠맨
               'UCmbGE7Y2ov7pTBuUrkXgtTQ' # 50. 할명수
              ]

# %%
print(len(channel_ids))
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        
        all_data.append(data)
    
    return all_data

channel_statistics = get_channel_stats(youtube, channel_ids)

channel_statistics
# Out:
# 53
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[227], line 20
#      16         all_data.append(data)
#      18     return all_data
# ---> 20 channel_statistics = get_channel_stats(youtube, channel_ids)
#      22 channel_statistics
#
# Cell In[227], line 7, in get_channel_stats(youtube, channel_ids)
#       3 all_data = []
#       4 request = youtube.channels().list(
#       5             part='snippet,contentDetails,statistics',
#       6             id=','.join(channel_ids))
# ----> 7 response = request.execute()
#       9 for i in range(len(response['items'])):
#      10     data = dict(Channel_name = response['items'][i]['snippet']['title'],
#      11                 Subscribers = response['items'][i]['statistics']['subscriberCount'],
#      12                 Views = response['items'][i]['statistics']['viewCount'],
# ...

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#          Channel_name Subscribers       Views Total_videos  \
# 0   쏘쏘한베이킹 sosobaking      289000    32318779          185
# 1   취미로 요리하는 남자 Yonam     1410000   150406028          100
# 2          레어리RareLee      648000   181527754          225
# 3          essential;     1160000   208113215          286
# 4               떴다왕언니      267000    80767723          295
# 5              바라던 바다      730000   362128253          519
# 6         해쭈 [HAEJOO]      672000   268424487          344
# 7                리틀면지          46        5411           31
# 8                재롱잔치      391000   143191310          251
# 9           웅이woongei     1200000   405191148          567
# 10          제이크 토익스피킹      104000    15170607          530
# 11                박웅장        1960     1189530           11
# 12  Cooking tree 쿠킹트리     4710000   476516906         1428
# 13          서담 seodam      859000   184072054          405
# 14               보통견주      287000   139086028          319
# ...

# %% [markdown]
# 한 유튜브의 채널 검색

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='재롱잔치', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ['WjoN93BcvKU',
#  'mKaJEL6Q6FE',
#  'QTbky1tPCm4',
#  '8efq41Wrq5U',
#  'EakDB-r-ETY',
#  'PDpHbhnHjZk',
#  'zSLnoo_8aKo',
#  'pEnZ9jIrGg8',
#  'WbdRJ-iM4lA',
#  '5XyiO2i7BA0',
#  'ynfBiCTj124',
#  'oE4GWYIZf7I',
#  '1Wt7fvUMFfI',
#  'Xc13mVUUPRs',
#  't494vpGxsik',
#  'NcDZqBBobDQ',
#  'ahqZENcYZC4',
#  'JCcv8QF3mXc',
#  'Z2tLR9fAMec',
#  'CuF6HxvV_5c',
#  'v12jhD4JdVo',
#  'zuffi-vXKsI',
#  'I5WZ12iu9Tc',
#  '-HtvgTxDkbU',
#  '6L4YbA8mMzA',
#  'PKRn8Ukv_8c',
#  'lg6Zq2dL-N8',
#  'C78QKorNjTg',
#  'b9obCImbNy8',
#  'EnUhhiiTVkI',
#  'iHOsOeZlISI',
#  'WLdT8_Ngwug',
#  'X60pxOg3kSY',
#  'dyjdYjr9UVo',
#  'bf5zOubql4w',
#  'oIRWIlAXnVA',
#  'MxRqgz6wyeU',
#  'oqQ_BaErze8',
#  '-VpOSll6w1s',
#  'XYLFgsYbU90',
#  'AEx3wEE_OiA',
#  'gYMEqjA4bss',
#  '0lYQ-3LSnhE',
#  'b5AMGEAyEOk',
#  'GOQYXRZPrE4',
#  'pu7yNeuj5KU',
#  '9A7wc3turAY',
#  'lb7zFTO7rvs',
#  'Awgbe-5h7oI',
#  'w3GQbjLBQLw',
#  'mN55Xveh1m0',
#  'RZE5irwJ4S0',
#  'PRQY6NbZQRU',
#  'MXWAaqJ6ttA',
#  'UD4Wty704wI',
# ...

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict( Title = video['snippet']['title'],
                                Published_date = video['snippet']['publishedAt'],
                                Views = video['statistics']['viewCount'],
                                Likes = video['statistics']['likeCount'],
                            

                               )
            try:
                Comments = video['statistics']['commentCount']
                # print(Comments)
            except:
                pass
            video_stats['Comments'] = Comments
            all_video_stats.append(video_stats)
            
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
video_data = pd.DataFrame(video_details)
video_data
# Out:
#                   Title        Published_date   Views Likes Comments
# 0       재롱이 잡지 화보 촬영한 날  2023-02-10T12:45:03Z   86785  5004      410
# 1         언니가 목운동도 시켜줘요  2023-02-08T13:30:07Z  134307  5596      470
# 2     엉덩이 씰룩거리면서 걷는 강아지  2023-02-03T12:30:11Z   49624  3010       94
# 3                 눈꽃 빙수  2023-02-01T12:00:06Z  123137  4984      442
# 4     재롱이는 설 연휴에 뭐 했냐면요  2023-01-27T12:15:02Z  174120  5797      375
# ..                  ...                   ...     ...   ...      ...
# 246  강아지 ASMR : 강아지 확대범  2020-10-09T09:28:00Z  189259  4458      226
# 247         코로 쇼핑하는 강아지  2020-10-05T10:30:03Z  156832  3956      226
# 248     고양이야 멍멍이야 하나만 해  2020-09-18T11:00:20Z  345285  8101      360
# 249           오늘 날씨는 재롱  2020-09-12T10:00:32Z   87218  2662      159
# 250    재롱이랑 강화도 잠깐 Vlog  2020-08-28T12:15:00Z  227712  5393      364
#
# [251 rows x 5 columns]
