# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
# %pip install google-api-python-client

# %%
# %pip install selenium

# %% [markdown]
# 채널 ID구하기

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
from oauth2client.tools import argparser
import requests
from bs4 import BeautifulSoup


# https://console.cloud.google.com/apis/credentials 여기서 API발급받아 사용
DEVELOPER_KEY='AIzaSyARrUg67ItiYT-d7vOnfp2Uo6otQQHYM5U' # 내 API 키값 입력
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube=build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
# q에 원하는 채널 이름 넣는다
search_response=youtube.search().list(
    q="무지막지한 막무가네",
    order='relevance',
    part='snippet',
    maxResults=50,
    ).execute()

# %%
search_response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'mcUFnA2pgKZyM6SUfhVEDkVLilo',
#  'id': {'kind': 'youtube#channel', 'channelId': 'UCLmeWUramUY8YAQ6A40Ionw'},
#  'snippet': {'publishedAt': '2019-05-09T12:32:00Z',
#   'channelId': 'UCLmeWUramUY8YAQ6A40Ionw',
#   'title': '무지막지한 막무家네',
#   'description': '무지와 막지의 일상을 담은 막무家네 채널입니다 :-) 무지 (muji) - 생일 : 2017.06.29 - 성별 : 남 (male) 막지 (makji) - 생일 ...',
#   'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AL5GRJUR3LL4L4xdzAkjnt_wHHfVxI-gnCQJw1DFqLum=s88-c-k-c0xffffffff-no-rj-mo'},
#    'medium': {'url': 'https://yt3.ggpht.com/ytc/AL5GRJUR3LL4L4xdzAkjnt_wHHfVxI-gnCQJw1DFqLum=s240-c-k-c0xffffffff-no-rj-mo'},
#    'high': {'url': 'https://yt3.ggpht.com/ytc/AL5GRJUR3LL4L4xdzAkjnt_wHHfVxI-gnCQJw1DFqLum=s800-c-k-c0xffffffff-no-rj-mo'}},
#   'channelTitle': '무지막지한 막무家네',
#   'liveBroadcastContent': 'upcoming',
#   'publishTime': '2019-05-09T12:32:00Z'}}

# %% [markdown]
# DataFrame으로 변환

# %%
api_key = 'AIzaSyARrUg67ItiYT-d7vOnfp2Uo6otQQHYM5U'
#channel_id = 'UCnz-ZXXER4jOvuED5trXfEA'
channel_ids = ['UC0SoPwEH3idvemSDvKaYgGA', # 달라스튜디오
               'UC0w2Xg4UB8ip-QnZnHpFB-g', # 재롱잔치
               'UCMZNsnZXi7IZZbCaPjjFBHw', # 지윤일기
               'UCKurJtf5TWo5nrq8nnuvrcg', # 꽉잡아윤기
               'UCQ2O-iftmnlfrBuNsUUTofQ', # 채널 십오야
               'UCr9fTGseL8WjLl0A_RubtZw', # 보통견주
               'UC3fPnB3ds2xBY1PTtgkCCYw', # ASTER MUSIC
               'UC98TOxKQk4aLcx0EjIK0LkQ', # 해수인 tv
               'UClWx6swfFdNod4hMeT27BBA', # 나는식물원에살고있다
               'UCLmeWUramUY8YAQ6A40Ionw' # 무지막지한 막무가네
            
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
youtube.channels().list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 youtube.channels().list()
#
# File c:\Users\user\anaconda3\envs\ml\lib\site-packages\googleapiclient\discovery.py:1063, in createMethod.<locals>.method(self, **kwargs)
#    1057     if name not in kwargs:
#    1058         # temporary workaround for non-paging methods incorrectly requiring
#    1059         # page token parameter (cf. drive.changes.watch vs. drive.changes.list)
#    1060         if name not in _PAGE_TOKEN_NAMES or _findPageTokenName(
#    1061             _methodProperties(methodDesc, schema, "response")
#    1062         ):
# -> 1063             raise TypeError('Missing required parameter "%s"' % name)
#    1065 for name, regex in parameters.pattern_params.items():
#    1066     if name in kwargs:
#
# TypeError: Missing required parameter "part"

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#         Channel_name Subscribers       Views Total_videos  \
# 0             달라스튜디오     1290000   318234605          231
# 1         무지막지한 막무家네      522000   106721618          290
# 2   꽉잡아윤기-Kwakyoongy     1060000   259455815          633
# 3               재롱잔치      391000   143133834          251
# 4        ASTER MUSIC      352000   103080559          458
# 5  해수인tv Hesuin BADA      566000   211342508          236
# 6     지윤일기Jiyundiary       19300     2938076          161
# 7         나는식물원에살고있다       64300    19586510          415
# 8             채널 십오야     5070000  1331753254          735
# 9               보통견주      287000   138948762          318
#
#                 playlist_id
# 0  UU0SoPwEH3idvemSDvKaYgGA
# 1  UULmeWUramUY8YAQ6A40Ionw
# 2  UUKurJtf5TWo5nrq8nnuvrcg
# 3  UU0w2Xg4UB8ip-QnZnHpFB-g
# 4  UU3fPnB3ds2xBY1PTtgkCCYw
# 5  UU98TOxKQk4aLcx0EjIK0LkQ
# 6  UUMZNsnZXi7IZZbCaPjjFBHw
# 7  UUlWx6swfFdNod4hMeT27BBA
# 8  UUQ2O-iftmnlfrBuNsUUTofQ
# 9  UUr9fTGseL8WjLl0A_RubtZw

# %% [markdown]
# 한 유튜브의 채널 검색

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='재롱잔치', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ['WjoN93BcvKU',
#  'mKaJEL6Q6FE',
#  'QTbky1tPCm4',
#  '8efq41Wrq5U',
#  'EakDB-r-ETY',
#  'PDpHbhnHjZk',
#  'zSLnoo_8aKo',
#  'pEnZ9jIrGg8',
#  'WbdRJ-iM4lA',
#  '5XyiO2i7BA0',
#  'ynfBiCTj124',
#  'oE4GWYIZf7I',
#  '1Wt7fvUMFfI',
#  'Xc13mVUUPRs',
#  't494vpGxsik',
#  'NcDZqBBobDQ',
#  'ahqZENcYZC4',
#  'JCcv8QF3mXc',
#  'Z2tLR9fAMec',
#  'CuF6HxvV_5c',
#  'v12jhD4JdVo',
#  'zuffi-vXKsI',
#  'I5WZ12iu9Tc',
#  '-HtvgTxDkbU',
#  '6L4YbA8mMzA',
#  'PKRn8Ukv_8c',
#  'lg6Zq2dL-N8',
#  'C78QKorNjTg',
#  'b9obCImbNy8',
#  'EnUhhiiTVkI',
#  'iHOsOeZlISI',
#  'WLdT8_Ngwug',
#  'X60pxOg3kSY',
#  'dyjdYjr9UVo',
#  'bf5zOubql4w',
#  'oIRWIlAXnVA',
#  'MxRqgz6wyeU',
#  'oqQ_BaErze8',
#  '-VpOSll6w1s',
#  'XYLFgsYbU90',
#  'AEx3wEE_OiA',
#  'gYMEqjA4bss',
#  '0lYQ-3LSnhE',
#  'b5AMGEAyEOk',
#  'GOQYXRZPrE4',
#  'pu7yNeuj5KU',
#  '9A7wc3turAY',
#  'lb7zFTO7rvs',
#  'Awgbe-5h7oI',
#  'w3GQbjLBQLw',
#  'mN55Xveh1m0',
#  'RZE5irwJ4S0',
#  'PRQY6NbZQRU',
#  'MXWAaqJ6ttA',
#  'UD4Wty704wI',
# ...

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict( Title = video['snippet']['title'],
                                Published_date = video['snippet']['publishedAt'],
                                Views = video['statistics']['viewCount'],
                                Likes = video['statistics']['likeCount'],
                            

                               )
            try:
                Comments = video['statistics']['commentCount']
                # print(Comments)
            except:
                pass
            video_stats['Comments'] = Comments
            all_video_stats.append(video_stats)
            
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
video_data = pd.DataFrame(video_details)
video_data
# Out:
#                   Title        Published_date   Views Likes Comments
# 0       재롱이 잡지 화보 촬영한 날  2023-02-10T12:45:03Z   86785  5004      410
# 1         언니가 목운동도 시켜줘요  2023-02-08T13:30:07Z  134307  5596      470
# 2     엉덩이 씰룩거리면서 걷는 강아지  2023-02-03T12:30:11Z   49624  3010       94
# 3                 눈꽃 빙수  2023-02-01T12:00:06Z  123137  4984      442
# 4     재롱이는 설 연휴에 뭐 했냐면요  2023-01-27T12:15:02Z  174120  5797      375
# ..                  ...                   ...     ...   ...      ...
# 246  강아지 ASMR : 강아지 확대범  2020-10-09T09:28:00Z  189259  4458      226
# 247         코로 쇼핑하는 강아지  2020-10-05T10:30:03Z  156832  3956      226
# 248     고양이야 멍멍이야 하나만 해  2020-09-18T11:00:20Z  345285  8101      360
# 249           오늘 날씨는 재롱  2020-09-12T10:00:32Z   87218  2662      159
# 250    재롱이랑 강화도 잠깐 Vlog  2020-08-28T12:15:00Z  227712  5393      364
#
# [251 rows x 5 columns]
