# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.8.0-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from selenium) (1.26.14)
# Collecting trio~=0.17
#   Using cached trio-0.22.0-py3-none-any.whl (384 kB)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from selenium) (2022.9.24)
# Requirement already satisfied: idna in c:\users\user\anaconda3\envs\ml\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\envs\ml\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting async-generator>=1.9
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sortedcontainers
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Using cached exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting outcome
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\envs\ml\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sortedcontainers, PySocks, outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed PySocks-1.7.1 async-generator-1.10 exceptiongroup-1.1.0 h11-0.14.0 outcome-1.2.0 selenium-4.8.0 sortedcontainers-2.4.0 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0

# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\user\anaconda3\envs\ml\lib\site-packages (2.76.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-python-client) (2.16.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.21.12)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.1)

# %%
import pandas
from googleapiclient.discovery import build

import warnings # 경고창 무시
warnings.filterwarnings('ignore')

# %%
# !pip install oauth2client
# Out:
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.2/98.2 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from oauth2client) (0.21.0)
# Requirement already satisfied: six>=1.6.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from oauth2client) (4.9)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from oauth2client) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.0.9)
# Installing collected packages: oauth2client
# Successfully installed oauth2client-4.1.3

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
from oauth2client.tools import argparser
import requests
from bs4 import BeautifulSoup


# https://console.cloud.google.com/apis/credentials 여기서 API발급받아 사용
DEVELOPER_KEY='AIzaSyARrUg67ItiYT-d7vOnfp2Uo6otQQHYM5U' # 내 API 키값 입력
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube=build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
# q에 원하는 채널 이름 넣는다
search_response=youtube.search().list(
    q="달라스튜디오",
    order='relevance',
    part='snippet',
    maxResults=50,
    ).execute()

# %%
search_response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '0pE8qGwuoSVKRROQQkJ36mzStuI',
#  'id': {'kind': 'youtube#channel', 'channelId': 'UC0SoPwEH3idvemSDvKaYgGA'},
#  'snippet': {'publishedAt': '2020-05-24T04:03:41Z',
#   'channelId': 'UC0SoPwEH3idvemSDvKaYgGA',
#   'title': '달라스튜디오',
#   'description': '달라스튜디오 우린 좀 달라! DALLA STUDIO! *비즈니스 문의 korea.aenetworks@gmail.com 비즈니스 문의는 위 공식 메일에 가장 ...',
#   'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AL5GRJVhxwaxGCPSZ3VGcJwZeUrT_LbkDsfBstgPSvNu=s88-c-k-c0xffffffff-no-rj-mo'},
#    'medium': {'url': 'https://yt3.ggpht.com/ytc/AL5GRJVhxwaxGCPSZ3VGcJwZeUrT_LbkDsfBstgPSvNu=s240-c-k-c0xffffffff-no-rj-mo'},
#    'high': {'url': 'https://yt3.ggpht.com/ytc/AL5GRJVhxwaxGCPSZ3VGcJwZeUrT_LbkDsfBstgPSvNu=s800-c-k-c0xffffffff-no-rj-mo'}},
#   'channelTitle': '달라스튜디오',
#   'liveBroadcastContent': 'upcoming',
#   'publishTime': '2020-05-24T04:03:41Z'}}

# %%
channel_id=search_response['items'][0]['id']['channelId']

# %%
playlists=youtube.playlists().list(
    channelId=channel_id,
    part='snippet',
    maxResults=20).execute()

# %%
import pandas as pd
ids=[]
titles=[]
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])
df=pd.DataFrame([ids,titles]).T
df.columns=['Playlists','Titles']
df
# Out:
#                              Playlists                              Titles
# 0   PLgLCwW8UTTGB3g-qOmFH2hLMqaD9I-MAr                              달라스튜디오
# 1   PLgLCwW8UTTGDHd_LRWOcHz6i90sJiCOZ1                   [동네가달라] 리얼 커뮤니티 쇼
# 2   PLgLCwW8UTTGA8sNgh_3XPbMWb_w95mPfv                    [대결왕] 신개념 게임 로드쇼
# 3   PLgLCwW8UTTGBBamceki0RPqtgmhUwuBKD                     [사달라] 4달라에 사달라!
# 4   PLgLCwW8UTTGBVFtYwuOJcK_vlXyuWmPIW                 [만나달라] 셀럽 셀프 홍보 의뢰쇼
# 5   PLgLCwW8UTTGCl3SRWx3Se4OvrK9Ynmzto                           달라 shorts
# 6   PLgLCwW8UTTGA0JEeyZEsBt0078qC34SxX                       [네고왕] 레전드의 귀환
# 7   PLgLCwW8UTTGCyNtNTQstJlE1FAblQL56D                  [인맥왕] 예측불가 릴레이 인터뷰
# 8   PLgLCwW8UTTGDsNm9TubK7s_vaNkeqTIOr                     [견적왕] 인생 고민 견적쇼
# 9   PLgLCwW8UTTGDHcnmELjOsuNSUh1WfMrt0                  [그늘집] 도심 속 신개념 토크쇼
# 10  PLgLCwW8UTTGCf5eouZPou3dH9MUUUBZA8           [네고왕3] 더 강력해진 선팩폭 후네고 시즌3
# 11  PLgLCwW8UTTGCT_gWUJNZxY-ksxwdahxMl             [완판왕] 완판 도전을 향한 대환장 라이브
# 12  PLgLCwW8UTTGBWjseCLLUaF8N6TXuLF-tn             [로또왕] 본격 로또 1등 번호 원정 예능
# 13  PLgLCwW8UTTGA_aHVoJeI3-H6RnUlz2bKi                  [네고왕2] 선팩폭 후네고 시즌2
# 14  PLgLCwW8UTTGCUR9eDijMeQzQefH9yFVl4  [배달그라운드] 배달 반경으로 잠입하라! 침샘 저격 배달 먹방
# 15  PLgLCwW8UTTGDcjQrZJxKmufLnCvivEGEA               [발명왕] 발명폭격기의 아이디어 대방출
# 16  PLgLCwW8UTTGB3njkVkAg-LGs_Cast_sbq                   [네고왕] 선팩폭 후네고 시즌1

# %%
nego=df['Playlists'][2]
playlists_videos=youtube.playlistItems().list(
    playlistId = nego,
    part = 'snippet',
    maxResults = 50)
playlistitems_list_response = playlists_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])

vdf=pd.DataFrame([date,video_names,video_ids]).T
vdf.columns=['Date','Title','IDS']
vdf
# Out:
#                     Date                                              Title  \
# 0   2022-07-20T09:29:59Z        선생님, 저랑 대결 하나 하시겠습니까? 맞짱 뜰 사람 구함 [대결왕] Ep.0
# 1   2022-07-27T09:29:58Z                한강을 뒤집어 놓은 도른자…가 우리 왕이라니 [대결왕] Ep.1
# 2   2022-08-03T09:29:56Z     빠지 대결하러 갔다가… 바지 벗고 극대노한 정 to the 혁  [대결왕] Ep.2
# 3   2022-08-10T07:11:19Z  엉덩이 너무 제 눈 앞에 있는 거 아니에요? 돌+I들의 방구석 찐친 대결🥊 (fea...
# 4   2022-08-17T09:50:59Z  민초 찍먹.. 민초 양치..🤢  '민친자' 속에 '반민초단'이 느껴진거야 [대결왕]...
# 5   2022-08-24T09:30:20Z            11군번이 재입대하는 일? 일어날수있으니 각오해라…⭐[대결왕] Ep.5
# 6   2022-09-06T09:30:45Z  인라인 3년 차가 아이스하키 하러 감 (여기서부터 잔인함) 근데 멈추질 못해.. [...
# 7   2022-09-13T09:33:22Z  ‘처음에 어떻게 해?’ 개그동아리 신입 MT에 91년생이 오면 생기는 일 [대결왕]...
# 8   2022-09-20T09:30:50Z     세상에 이런 MT 게임은 없었다.. 이것은 초음파인가 괴성인가🔊 [대결왕] Ep.8
# 9   2022-09-27T09:30:05Z          아마존에서 머리부터 양말까지 다다 젖어버린💦대결좌 정혁 [대결왕] Ep.9
# 10  2022-10-04T09:30:54Z  100만원 걸고💵 기네스 기록 도전하다가 마지막까지 쓰껄rr한 정혁 [대결왕] Ep.10
#
#             IDS
# 0   iBXGJGm-sfs
# 1   gBbcq6DbRCE
# 2   wMteLXFri2g
# 3   G-XSDZI1K2o
# 4   EVXA7kTvokY
# 5   J9MfgtI0ltY
# 6   R_nL36aK-lM
# 7   GdIcod4nq_I
# 8   30IxhMDuRq8
# 9   ZB6epP2b-dk
# 10  IgPP0Zjb_rM

# %%
#영상 관련 수치
import re

category_id=[]
views=[]
likes=[]
# dislikes=[]
comments=[]
mins=[]
seconds=[]
title=[]
date=[]

for u in range(len(vdf)):
    request=youtube.videos().list(
    part='snippet,contentDetails,statistics',
    id=vdf['IDS'][u])
    
    response=request.execute()
    
    if response['items']==[]:
        ids.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        # dislikes.append('-')
        comments.append('-')
        date.append('-')
        
    else :
        title.append(response['items'][0]['snippet']['title'])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        # dislikes.append(response['items'][0]['statistics']['dislikeCount'])
        comments.append(response['items'][0]['statistics']['commentCount']) # commentCount가 있는게 있고 없는게 있다.
        date.append(response['items'][0]['snippet']['publishedAt'])

# %%
nego_df=pd.DataFrame([title, category_id, views, likes, comments]).T
nego_df.columns = ['title','category_id','views','likes','comments']
nego_df
# Out:
#                                                 title category_id   views  \
# 0         선생님, 저랑 대결 하나 하시겠습니까? 맞짱 뜰 사람 구함 [대결왕] Ep.0          23  104522
# 1                 한강을 뒤집어 놓은 도른자…가 우리 왕이라니 [대결왕] Ep.1          23  109740
# 2      빠지 대결하러 갔다가… 바지 벗고 극대노한 정 to the 혁  [대결왕] Ep.2          23  362353
# 3   엉덩이 너무 제 눈 앞에 있는 거 아니에요? 돌+I들의 방구석 찐친 대결🥊 (fea...          23  274259
# 4   민초 찍먹.. 민초 양치..🤢  '민친자' 속에 '반민초단'이 느껴진거야 [대결왕]...          23  587545
# 5             11군번이 재입대하는 일? 일어날수있으니 각오해라…⭐[대결왕] Ep.5          23  573607
# 6   인라인 3년 차가 아이스하키 하러 감 (여기서부터 잔인함) 근데 멈추질 못해.. [...          23   83363
# 7   ‘처음에 어떻게 해?’ 개그동아리 신입 MT에 91년생이 오면 생기는 일 [대결왕]...          23   85223
# 8      세상에 이런 MT 게임은 없었다.. 이것은 초음파인가 괴성인가🔊 [대결왕] Ep.8          23   49308
# 9           아마존에서 머리부터 양말까지 다다 젖어버린💦대결좌 정혁 [대결왕] Ep.9          23  275453
# 10  100만원 걸고💵 기네스 기록 도전하다가 마지막까지 쓰껄rr한 정혁 [대결왕] Ep.10          23  279544
#
#    likes comments
# 0    770      114
# 1   1438      141
# 2    959       80
# 3   1110      100
# 4   1067       96
# 5    809       80
# 6    427       56
# 7    327       30
# 8    228       26
# 9    352       29
# 10   278       30

# %%
https://yobro.tistory.com/190
# Out:
#   Cell In[73], line 1
#     https://yobro.tistory.com/190
#           ^
# SyntaxError: invalid syntax
